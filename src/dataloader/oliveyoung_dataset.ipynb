# %%
import pandas as pd
df1 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-12.csv")
df2 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-24.csv")
df3 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-36.csv")
df4 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-48.csv")
df5 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-60.csv")
df6 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-72.csv")
df7 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-90.csv")
df8 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-105.csv")
df9 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-119.csv")
df10 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-132.csv")
df11 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-147.csv")
df12 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-159.csv")
df13 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-179.csv")
df14 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-199.csv")
df15 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/cream/크림-214.csv")
df_cream = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15], axis=0, ignore_index=True)

# %%
df1 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/essence/에센스-세럼-앰플-52.csv")
df2 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/essence/에센스-세럼-앰플-64.csv")
df3 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/essence/에센스-세럼-앰플-76.csv")
df4 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/essence/에센스-세럼-앰플-89.csv")
df5 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/essence/에센스-세럼-앰플-103.csv")
df6 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/essence/에센스-세럼-앰플-115.csv")
df7 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/essence/에센스-세럼-앰플-128.csv")
df8 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/essence/에센스-세럼-앰플-145.csv")
df9 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/essence/에센스-세럼-앰플-164.csv")
df10 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/essence/에센스-세럼-앰플-180.csv")
df11 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/essence/에센스-세럼-앰플-final.csv")
df_essence = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11], axis=0, ignore_index=True)
df_essence['rate'] = df_essence['rate'].replace([float('nan'), float('inf')], 0).astype(int)
df_essence
# Out:
#       nickname                           brand   category  rate skin_type  \
# 0          와플리  프리메라 유스 래디언스 비타티놀 세럼 15g 단품/기획  에센스-세럼-앰플     5   건성에 좋아요
# 1         마찌마찌  프리메라 유스 래디언스 비타티놀 세럼 15g 단품/기획  에센스-세럼-앰플     4   건성에 좋아요
# 2        동인이에용  프리메라 유스 래디언스 비타티놀 세럼 15g 단품/기획  에센스-세럼-앰플     5   건성에 좋아요
# 3           서닛  프리메라 유스 래디언스 비타티놀 세럼 15g 단품/기획  에센스-세럼-앰플     5   건성에 좋아요
# 4       yuna09  프리메라 유스 래디언스 비타티놀 세럼 15g 단품/기획  에센스-세럼-앰플     5   지성에 좋아요
# ...        ...                             ...        ...   ...       ...
# 11345       공6           로벡틴 시카케어 클리어링 앰플 30ml  에센스-세럼-앰플     5  복합성에 좋아요
# 11346  0onggii           로벡틴 시카케어 클리어링 앰플 30ml  에센스-세럼-앰플     3   지성에 좋아요
# 11347    쭈니쭌투맘           로벡틴 시카케어 클리어링 앰플 30ml  에센스-세럼-앰플     5   지성에 좋아요
# 11348  0onggii           로벡틴 시카케어 클리어링 앰플 30ml  에센스-세럼-앰플     3   지성에 좋아요
# 11349   불타는병아리           로벡틴 시카케어 클리어링 앰플 30ml  에센스-세럼-앰플     5   건성에 좋아요
#
#       select_1_content select_2_content select_3_content  \
# ...

# %%
df1 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/lotion/로션-15.csv")
df2 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/lotion/로션-32.csv")
df3 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/lotion/로션-51.csv")
df4 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/lotion/로션-82.csv")
df5 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/lotion/로션-131.csv")
df6 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/lotion/로션-170.csv")
df7 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/lotion/로션-final.csv")
df_lotion = pd.concat([df1, df2, df3, df4, df5, df6, df7], axis=0, ignore_index=True)
df_lotion['rate'] = df_lotion['rate'].replace([float('nan'), float('inf')], 0).astype(int)
df_lotion
# Out:
#          nickname                             brand category  rate skin_type  \
# 0          보리언니S2  피지오겔 DMT 페이셜 로션 200ml+50ml 증정 기획       로션     4   지성에 좋아요
# 1            부릉부릉  피지오겔 DMT 페이셜 로션 200ml+50ml 증정 기획       로션     5   건성에 좋아요
# 2             빛날율  피지오겔 DMT 페이셜 로션 200ml+50ml 증정 기획       로션     4  복합성에 좋아요
# 3            올리브9  피지오겔 DMT 페이셜 로션 200ml+50ml 증정 기획       로션     5  복합성에 좋아요
# 4          licool  피지오겔 DMT 페이셜 로션 200ml+50ml 증정 기획       로션     5   건성에 좋아요
# ...           ...                               ...      ...   ...       ...
# 6915      big****      랩시리즈 데일리 레스큐 하이드레이팅 에멀전 50ml       로션     1  복합성에 좋아요
# 6916  juvenil****      랩시리즈 데일리 레스큐 하이드레이팅 에멀전 50ml       로션     5  복합성에 좋아요
# 6917        Queen      랩시리즈 데일리 레스큐 하이드레이팅 에멀전 50ml       로션     4  복합성에 좋아요
# 6918         보더콜리      랩시리즈 데일리 레스큐 하이드레이팅 에멀전 50ml       로션     5  복합성에 좋아요
# 6919         메리마미      랩시리즈 데일리 레스큐 하이드레이팅 에멀전 50ml       로션     5  복합성에 좋아요
#
# ...

# %%
df1 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/oil/미스트-오일-17.csv")
df2 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/oil/미스트-오일-31.csv")
df_oil = pd.concat([df1, df2], axis=0, ignore_index=True)
df_oil
# Out:
#         nickname                         brand category  rate skin_type  \
# 0            말티츄  달바 화이트 트러플 퍼스트 스프레이 세럼 100ml   미스트-오일     4   지성에 좋아요
# 1            무미니  달바 화이트 트러플 퍼스트 스프레이 세럼 100ml   미스트-오일     5   건성에 좋아요
# 2            효둉해  달바 화이트 트러플 퍼스트 스프레이 세럼 100ml   미스트-오일     3  복합성에 좋아요
# 3             뜀틀  달바 화이트 트러플 퍼스트 스프레이 세럼 100ml   미스트-오일     5   건성에 좋아요
# 4           딸기케잌  달바 화이트 트러플 퍼스트 스프레이 세럼 100ml   미스트-오일     4  복합성에 좋아요
# ...          ...                           ...      ...   ...       ...
# 2095       모찌곰유진     자트인사이트 울트라 셋팅 진짜 픽서 110ml   미스트-오일     5  복합성에 좋아요
# 2096          라한     자트인사이트 울트라 셋팅 진짜 픽서 110ml   미스트-오일     5  복합성에 좋아요
# 2097        소비왕왕     자트인사이트 울트라 셋팅 진짜 픽서 110ml   미스트-오일     5  복합성에 좋아요
# 2098  닉닉닉닉닉닉닉닉닉닉     자트인사이트 울트라 셋팅 진짜 픽서 110ml   미스트-오일     5   지성에 좋아요
# 2099        딜리브영     자트인사이트 울트라 셋팅 진짜 픽서 110ml   미스트-오일     5   건성에 좋아요
#
#      select_1_content select_2_content select_3_content  \
# ...

# %%
df1 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-40.csv")
df2 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-55.csv")
df3 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-68.csv")
df4 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-89.csv")
df5 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-112.csv")
df6 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-139.csv")
df7 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-166.csv")
df8 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-190.csv")
df9 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-212.csv")
df10 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-238.csv")
df11 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-271.csv")
df12 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-299.csv")
df13 = pd.read_csv("C:/Users/SBA/Desktop/cosmetic_datastet/skin/스킨-토너-final.csv")
df_skin = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13], axis=0, ignore_index=True)
df_skin['rate'] = df_skin['rate'].replace([float('nan'), float('inf')], 0).astype(int)
df_skin
# Out:
#           nickname                          brand category  rate skin_type  \
# 0              쇼쇼정  아벤느 이드랑스 딥모이스트 로션 200ml 더블 기획    스킨-토너     5   건성에 좋아요
# 1             부부로부  아벤느 이드랑스 딥모이스트 로션 200ml 더블 기획    스킨-토너     5   지성에 좋아요
# 2        alice****  아벤느 이드랑스 딥모이스트 로션 200ml 더블 기획    스킨-토너     1   건성에 좋아요
# 3               비늉  아벤느 이드랑스 딥모이스트 로션 200ml 더블 기획    스킨-토너     5   건성에 좋아요
# 4            날마다연어  아벤느 이드랑스 딥모이스트 로션 200ml 더블 기획    스킨-토너     5   건성에 좋아요
# ...            ...                            ...      ...   ...       ...
# 12345       nt****   스킨1004 마다가스카르 센텔라 토닝토너 210ml    스킨-토너     5   지성에 좋아요
# 12346    hyuns****   스킨1004 마다가스카르 센텔라 토닝토너 210ml    스킨-토너     5   건성에 좋아요
# 12347    ohkyo****   스킨1004 마다가스카르 센텔라 토닝토너 210ml    스킨-토너     5  복합성에 좋아요
# 12348    jeong****   스킨1004 마다가스카르 센텔라 토닝토너 210ml    스킨-토너     5  복합성에 좋아요
# 12349  sungwoo****   스킨1004 마다가스카르 센텔라 토닝토너 210ml    스킨-토너     5  복합성에 좋아요
#
#       select_1_content select_2_content select_3_content  \
# ...

# %%
df = pd.concat([df_cream, df_essence, df_lotion, df_oil, df_skin])
df
# Out:
#           nickname                              brand category  rate  \
# 0              툔탸로  피지오겔 DMT 페이셜 크림 100ml+100ml 증정 기획       크림     5
# 1            vanta  피지오겔 DMT 페이셜 크림 100ml+100ml 증정 기획       크림     2
# 2           보리언니S2  피지오겔 DMT 페이셜 크림 100ml+100ml 증정 기획       크림     5
# 3            리리578  피지오겔 DMT 페이셜 크림 100ml+100ml 증정 기획       크림     5
# 4           gn4343  피지오겔 DMT 페이셜 크림 100ml+100ml 증정 기획       크림     5
# ...            ...                                ...      ...   ...
# 12345       nt****       스킨1004 마다가스카르 센텔라 토닝토너 210ml    스킨-토너     5
# 12346    hyuns****       스킨1004 마다가스카르 센텔라 토닝토너 210ml    스킨-토너     5
# 12347    ohkyo****       스킨1004 마다가스카르 센텔라 토닝토너 210ml    스킨-토너     5
# 12348    jeong****       스킨1004 마다가스카르 센텔라 토닝토너 210ml    스킨-토너     5
# 12349  sungwoo****       스킨1004 마다가스카르 센텔라 토닝토너 210ml    스킨-토너     5
#
#       skin_type select_1_content select_2_content select_3_content  \
# 0      복합성에 좋아요         복합성에 좋아요          보습에 좋아요         자극없이 순해요
# ...

# %%
# csv 파일 저장
# df.to_csv('cosmetic_dataset2.csv', encoding='utf-8')

# %%
# text = '이즈앤트리 어니언 뉴페어 겔크림 50ml 기획'
# split_list = text.split(' ')
# for i in split_list:

# %% [markdown]
# ## brand 이름 정제하기

# %%
import re
def normalize_brand(brand_string):
    normalized_brand = re.sub(r'\[.*?\]|\(.*?\)', '', brand_string).strip().replace("  ", " ")
    return normalized_brand
df['brand'] = df['brand'].apply(normalize_brand)

# %%
d = pd.DataFrame(df['brand'].value_counts()).reset_index()
d['split'] = d['brand'].apply(lambda x: x.split(' '))

d.head()
# Out:
#                            brand  count                                  split
# 0          식물나라 카렌둘라 진정 토너 500ml    180            [식물나라, 카렌둘라, 진정, 토너, 500ml]
# 1  아벤느 이드랑스 딥모이스트 로션 200ml 더블 기획    180  [아벤느, 이드랑스, 딥모이스트, 로션, 200ml, 더블, 기획]
# 2         아누아 어성초 80 수분 진정 앰플 기획    100         [아누아, 어성초, 80, 수분, 진정, 앰플, 기획]
# 3           닥터디퍼런트 스케일링 토너 200ml    100              [닥터디퍼런트, 스케일링, 토너, 200ml]
# 4   BRTC 트레이너 옴므 올인원 밀크 200ml 기획    100   [BRTC, 트레이너, 옴므, 올인원, 밀크, 200ml, 기획]

# %%
def split_list(s_list):
    for idx, values in enumerate(s_list):
        if ('ml' in values) | ('mL' in values) :
            return idx

# %%
d['ml_idx'] = d['split'].apply(split_list)

# %%
d = d.dropna()

# %%
d.head()
# Out:
#                            brand  count  \
# 0          식물나라 카렌둘라 진정 토너 500ml    180
# 1  아벤느 이드랑스 딥모이스트 로션 200ml 더블 기획    180
# 3           닥터디퍼런트 스케일링 토너 200ml    100
# 4   BRTC 트레이너 옴므 올인원 밀크 200ml 기획    100
# 6          포맨트 시그니처 올인원 에센스 96ml     90
#
#                                    split  ml_idx
# 0            [식물나라, 카렌둘라, 진정, 토너, 500ml]     4.0
# 1  [아벤느, 이드랑스, 딥모이스트, 로션, 200ml, 더블, 기획]     4.0
# 3              [닥터디퍼런트, 스케일링, 토너, 200ml]     3.0
# 4   [BRTC, 트레이너, 옴므, 올인원, 밀크, 200ml, 기획]     5.0
# 6            [포맨트, 시그니처, 올인원, 에센스, 96ml]     4.0

# %%
def join_split_data(df):
    result =  ' '.join(df['split'][:df['ml_idx']])
    return result

# %%
d['ml_idx'] = d.loc[:,'ml_idx'].astype(int)

# %%
d['result'] = d.apply(join_split_data, axis =1 )
d
# Out:
#                                      brand  count  \
# 0                    식물나라 카렌둘라 진정 토너 500ml    180
# 1            아벤느 이드랑스 딥모이스트 로션 200ml 더블 기획    180
# 3                     닥터디퍼런트 스케일링 토너 200ml    100
# 4             BRTC 트레이너 옴므 올인원 밀크 200ml 기획    100
# 6                    포맨트 시그니처 올인원 에센스 96ml     90
# ..                                     ...    ...
# 772  디오디너리 비타민C 서스펜션 23% + HA 스피어스 2% 30ml     10
# 774           플리프 시카-알로에 프레쉬 로션 200ml 기획세트     10
# 775        크리니크 모이스춰 써지 쏙보습크림/리치크림 50ml 기획     10
# 776           다슈 맨즈 아쿠아 딥 워터풀 올인원 로션 153ml     10
# 777           포엘리에 옴므 올인원 5IN1 퍼펙트로션 150ml     10
#
#                                                split  ml_idx  \
# 0                        [식물나라, 카렌둘라, 진정, 토너, 500ml]       4
# 1              [아벤느, 이드랑스, 딥모이스트, 로션, 200ml, 더블, 기획]       4
# 3                          [닥터디퍼런트, 스케일링, 토너, 200ml]       3
# 4               [BRTC, 트레이너, 옴므, 올인원, 밀크, 200ml, 기획]       5
# ...

# %%
merge_df = pd.merge(df, d, on='brand', how='right')
merge_df
# Out:
#          nickname                         brand category  rate skin_type  \
# 0        gksd****         식물나라 카렌둘라 진정 토너 500ml    스킨-토너     5  복합성에 좋아요
# 1        기상청보면서기상         식물나라 카렌둘라 진정 토너 500ml    스킨-토너     4  복합성에 좋아요
# 2            미미네라         식물나라 카렌둘라 진정 토너 500ml    스킨-토너     5  복합성에 좋아요
# 3          NUNU88         식물나라 카렌둘라 진정 토너 500ml    스킨-토너     5  복합성에 좋아요
# 4             잉경잉         식물나라 카렌둘라 진정 토너 500ml    스킨-토너     5  복합성에 좋아요
# ...           ...                           ...      ...   ...       ...
# 39925       Visit  포엘리에 옴므 올인원 5IN1 퍼펙트로션 150ml       로션     5  복합성에 좋아요
# 39926  올영기둥하나내가세움  포엘리에 옴므 올인원 5IN1 퍼펙트로션 150ml       로션     5  복합성에 좋아요
# 39927      HYUN22  포엘리에 옴므 올인원 5IN1 퍼펙트로션 150ml       로션     5  복합성에 좋아요
# 39928       올영리린이  포엘리에 옴므 올인원 5IN1 퍼펙트로션 150ml       로션     4   지성에 좋아요
# 39929    sssysgsh  포엘리에 옴므 올인원 5IN1 퍼펙트로션 150ml       로션     5   건성에 좋아요
#
#       select_1_content select_2_content select_3_content  \
# ...

# %%
merge_df.drop(['count','split','ml_idx'], axis=1, inplace=True)

# %%
merge_df
# Out:
#          nickname                         brand category  rate skin_type  \
# 0        gksd****         식물나라 카렌둘라 진정 토너 500ml    스킨-토너     5  복합성에 좋아요
# 1        기상청보면서기상         식물나라 카렌둘라 진정 토너 500ml    스킨-토너     4  복합성에 좋아요
# 2            미미네라         식물나라 카렌둘라 진정 토너 500ml    스킨-토너     5  복합성에 좋아요
# 3          NUNU88         식물나라 카렌둘라 진정 토너 500ml    스킨-토너     5  복합성에 좋아요
# 4             잉경잉         식물나라 카렌둘라 진정 토너 500ml    스킨-토너     5  복합성에 좋아요
# ...           ...                           ...      ...   ...       ...
# 39925       Visit  포엘리에 옴므 올인원 5IN1 퍼펙트로션 150ml       로션     5  복합성에 좋아요
# 39926  올영기둥하나내가세움  포엘리에 옴므 올인원 5IN1 퍼펙트로션 150ml       로션     5  복합성에 좋아요
# 39927      HYUN22  포엘리에 옴므 올인원 5IN1 퍼펙트로션 150ml       로션     5  복합성에 좋아요
# 39928       올영리린이  포엘리에 옴므 올인원 5IN1 퍼펙트로션 150ml       로션     4   지성에 좋아요
# 39929    sssysgsh  포엘리에 옴므 올인원 5IN1 퍼펙트로션 150ml       로션     5   건성에 좋아요
#
#       select_1_content select_2_content select_3_content  \
# ...

# %%
# 'brand' 열의 내용을 'result' 열 내용으로 바꾸기
merge_df['brand'] = merge_df['result']

# 'result' 열 제거
df = merge_df.drop(['result'], axis=1)

# %%
df
# Out:
#          nickname                   brand category  rate skin_type  \
# 0        gksd****         식물나라 카렌둘라 진정 토너    스킨-토너     5  복합성에 좋아요
# 1        기상청보면서기상         식물나라 카렌둘라 진정 토너    스킨-토너     4  복합성에 좋아요
# 2            미미네라         식물나라 카렌둘라 진정 토너    스킨-토너     5  복합성에 좋아요
# 3          NUNU88         식물나라 카렌둘라 진정 토너    스킨-토너     5  복합성에 좋아요
# 4             잉경잉         식물나라 카렌둘라 진정 토너    스킨-토너     5  복합성에 좋아요
# ...           ...                     ...      ...   ...       ...
# 39925       Visit  포엘리에 옴므 올인원 5IN1 퍼펙트로션       로션     5  복합성에 좋아요
# 39926  올영기둥하나내가세움  포엘리에 옴므 올인원 5IN1 퍼펙트로션       로션     5  복합성에 좋아요
# 39927      HYUN22  포엘리에 옴므 올인원 5IN1 퍼펙트로션       로션     5  복합성에 좋아요
# 39928       올영리린이  포엘리에 옴므 올인원 5IN1 퍼펙트로션       로션     4   지성에 좋아요
# 39929    sssysgsh  포엘리에 옴므 올인원 5IN1 퍼펙트로션       로션     5   건성에 좋아요
#
#       select_1_content select_2_content select_3_content  \
# 0             복합성에 좋아요          진정에 좋아요         자극없이 순해요
# ...

# %%
# csv 파일 저장
# df.to_csv('final_cosmetic_dataset.csv', index=False)
